# %% [markdown]
# <a href="https://colab.research.google.com/github/sanu1230/Academic-Project/blob/master/Time_Series_Analysis_Air_Passengers_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time Series Analysis on Air Passengers data

# %% [markdown]
# ### Table of contents:
# - <a href='#1'>1.Importing data</a>
# - <a href='#2'>2.Plotting the data</a>
# - <a href='#3'>3.Check Stationarity</a>
# - <a href='#4'>4.Log Transformation</a>
# - <a href='#5'>5.Simple moving average</a>
# - <a href='#6'>6.Exponentially weighted moving average </a>
# - <a href='#7'>7.Eliminating Trend and Seasonality</a>
# - <a href='#8'>8.ACF and PACF plots</a>
# - <a href='#9'>9.Algorithm Selection</a>
# - <a href='#10'>10. Auto ARIMA</a>

# %% [markdown]
# ## <a id='1'>1. Importing the data</a>

# %%
# !pip install git+https://github.com/statsmodels/statsmodels.git
# Out:
# Collecting git+https://github.com/statsmodels/statsmodels.git
#   Cloning https://github.com/statsmodels/statsmodels.git to /tmp/pip-req-build-2jvetzcd
#   Running command git clone -q https://github.com/statsmodels/statsmodels.git /tmp/pip-req-build-2jvetzcd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied (use --upgrade to upgrade): statsmodels==0.12.0.dev0+647.gcb99c88c1 from git+https://github.com/statsmodels/statsmodels.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from statsmodels==0.12.0.dev0+647.gcb99c88c1) (1.18.5)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.6/dist-packages (from statsmodels==0.12.0.dev0+647.gcb99c88c1) (1.0.5)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.6/dist-packages (from statsmodels==0.12.0.dev0+647.gcb99c88c1) (1.4.1)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels==0.12.0.dev0+647.gcb99c88c1) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->statsmodels==0.12.0.dev0+647.gcb99c88c1) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21->statsmodels==0.12.0.dev0+647.gcb99c88c1) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->statsmodels==0.12.0.dev0+647.gcb99c88c1) (1.15.0)
# Building wheels for collected packages: statsmodels
#   Building wheel for statsmodels (PEP 517) ... done
#   Created wheel for statsmodels: filename=statsmodels-0.12.0.dev0+647.gcb99c88c1-cp36-cp36m-linux_x86_64.whl size=16949125 sha256=fe9843322ae2852c8570587a7f836a6f91226e1da8f5e860973eb4b05a674592
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9s8p7o7p/wheels/7b/bd/6d/3192a61f34609bda0eea70342907984dba2ad17c3abb502ce7
# Successfully built statsmodels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/4b/15/0dfc38deb2f5582b79baff6523b245d6a3dbe877e3fb96a1ee39ec63b626/pmdarima-1.6.1-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 4.4MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.18.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.0.5)
# Requirement already satisfied: statsmodels>=0.11 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.12.0.dev0+647.gcb99c88c1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from pmdarima) (0.16.0)
# Collecting Cython<0.29.18,>=0.29
#   Downloading https://files.pythonhosted.org/packages/e7/d7/510ddef0248f3e1e91f9cc7e31c0f35f8954d0af92c5c3fd4c853e859ebe/Cython-0.29.17-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 30.1MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.15.0)
# Installing collected packages: Cython, pmdarima
#   Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
# Successfully installed Cython-0.29.17 pmdarima-1.6.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Loading the dataset
df =  pd.read_csv("/content/drive/My Drive/Colab Notebooks/UpX/Time_Series/AirPassewngers_Data/AirPassengers.csv", header = 0, parse_dates = [0], names = ['Month', 'Passengers'])
df.head()
# Out:
#        Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %% [markdown]
# Top 5 rows of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %% [markdown]
# **Observations:**  Notice the dtype=’datetime[ns]’ which confirms that it is a datetime object. <br>
# No of rows: 144<br/>
# No.of columns: 2<br/>

# %%
df.describe()
# Out:
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %% [markdown]
# **Missing values if any**

# %%
df.isnull().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
ts = df.set_index('Month', drop=True)

# %%
ts.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# **Note:** Now we can see that the data has **month** object as index and **Passengers** as column.

# %% [markdown]
# ## <a id='2'>2. Plotting the data</a>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot(ts)
plt.title('Air Passengers from 1949 to 1960 in thousands')
plt.show();

# %% [markdown]
# **Observations:**<br/>
# From the above plot, it is clear that there is an increasing trend as more and more people are taking flights.

# %% [markdown]
# ### Stationary

# %% [markdown]
# *A TS is said to be stationary if its statistical properties such as mean, variance remain constant over time.*<br/>
#
#
# **But why is it important?** <br/>
# Most of the TS models work on the assumption that the TS is stationary. Intuitively, we can say that if a TS has a particular behaviour over time, there is a very high probability that it will follow the same in the future.
#
# *There are three basic criterion for a series to be classified as stationary series :*
#
# 1. Constant mean
# 2. Constant variance
# 3. an autocovariance that does not depend on time.
#
# **Why do I care about ‘stationarity’ of a time series?**<br/>
# The reason is that until unless your time series is stationary, you cannot build a time series model. In cases where the stationary criterion are violated, the first requisite becomes to stationarize the time series and then try models to predict this time series.

# %% [markdown]
# ## <a id='3'>3. Check Stationarity of time series</a>
#
# Stationary testing and converting a series into a stationary series are the most critical processes in a time series modelling.
#
# **Plotting Rolling Statistics:** We can plot the moving average or moving variance and see if it varies with time. By moving average/variance I mean that at any instant ‘t’, we’ll take the average/variance of the last year, i.e. last 12 months. But again this is more of a visual technique.
#
# **Dickey-Fuller Test:** This is one of the statistical tests for checking stationarity.
#
# 1. *Null hypothesis is that the TS is non-stationary.* <br/>
# 2. *The test results comprise of a Test Statistic and some Critical Values for difference confidence levels.* <br/>
# 3. *If the ‘Test Statistic’ is less than the ‘Critical Value’, we can reject the null hypothesis and say that the series is stationary.*

# %% [markdown]
# **Note:** I have defined a function to use rolling statistics plots along with Dickey-Fuller test results to check stationarity.

# %%
#Perform Dickey-Fuller test:
from statsmodels.tsa.stattools import adfuller

# %%
def test_stationarity(timeseries):
    print("Results of Dickey-Fuller Test:")
    result = adfuller(timeseries,autolag='AIC')
    labels=['Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result, labels):
        print(label+ " : "+str(value))

    if result[1] <= 0.05:
        print("Reject the null hypothesis. Data is stationary")
    else:
        print("Fail to reject the null hypothesis. Data is non-stationary")

# %%
test_stationarity(ts['Passengers'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic : 0.815368879206047
# p-value : 0.991880243437641
# #Lags Used : 13
# Number of Observations Used : 130
# Fail to reject the null hypothesis. Data is non-stationary

# %%
#Determing rolling statistics
rolmean = ts['Passengers'].rolling(12).mean()
rolstd = ts['Passengers'].rolling(12).std()

#Plot rolling statistics:
import matplotlib.pyplot as
plt.figure(figsize=(20,5))
orig = plt.plot(ts['Passengers'], color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.figure(figsize=(20,5))
plt.show(block=False)

# %% [markdown]
# **Observations:**<br/>
# Though the variation in standard deviation is small, mean is clearly increasing with time and this is not a stationary series. Also, the test statistic is more than the critical values. p-value also greater than threshold(0.05). Accept null hypothesis.

# %% [markdown]
# ### <a id='3'> **How to make a Time Series Stationary?** </a>
#
# Lets understand what is making a TS non-stationary. There are 2 major reasons behind non-stationarity of a TS:
# 1. **Trend** – varying mean over time.
# 2. **Seasonality** – variations at specific time-frames.
#
# *The main principle is to model or estimate the trend and seasonality in the series and remove those from the series to get a stationary series.*
#
# **One of the first ways to reduce trend can be transformation**. So we can apply transformation which penalize higher values more than smaller values. These can be taking a log, square root, cube root, etc.

# %% [markdown]
# ## <a id='4'> 4. Log transformation </a>

# %%
plt.figure(figsize=(20,5))
ts_log = np.log(ts)
plt.plot(ts_log)
plt.title('Log of Data')
plt.show()

# %% [markdown]
# **Note:** It is not easy to see a trend in the data, in presence of noise. So we can use smoothing techniques(taking rolling averages) to estimate or model this trend and then remove it from the series.
#
# *Smoothing refers to taking rolling estimates, i.e. considering the past few instances.*
# 1. Simple Moving average
# 2. Weighted Moving average
# 3. Exponential smoothing

# %% [markdown]
# ## <a id='5'> 5. Simple Moving Average </a><br/>
#
# In this approach, we take average of ‘k’ consecutive values depending on the frequency of time series. Here we can take the average over the past 1 year, i.e. last 12 values.

# %%
plt.figure(figsize=(20,5))
moving_avg = ts_log.rolling(12).mean()
plt.plot(ts_log)
plt.plot(moving_avg, color='red')
plt.title('Log of Data Vs Moving Average of Log of Data', fontsize=20)
plt.show()

# %%
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(12) #Notice the first 11 being Nan. Lets drop these NaN values and check the plots to test stationarity.
ts_log_moving_avg_diff.dropna(inplace=True)
test_stationarity(ts_log_moving_avg_diff.Passengers) # Appliying the function created earlier
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic : -3.162907991300857
# p-value : 0.022234630001243903
# #Lags Used : 13
# Number of Observations Used : 119
# Reject the null hypothesis. Data is stationary

# %% [markdown]
# **Observations:** Reject Null Hypothesis.. Time Series is stationary.

# %% [markdown]
# However, a drawback in this particular approach is that the *time-period has to be strictly defined*. In this case we can take yearly averages but in *complex situations like forecasting a stock price, its difficult to come up with a number*. So we take a **‘weighted moving average’ where more recent values are given a higher weight.** There can be many technique for assigning weights. **A popular one is exponentially weighted moving average where weights are assigned to all the previous values with a decay factor.** Find details here. This can be implemented in Pandas as:

# %% [markdown]
# ## <a id='5.1'> 6. Exponentially weighted moving average </a><br/>
# Weights are assigned to all the previous values with a decay factor.

# %%
# from matplotlib import pyplot
plt.figure(figsize=(20,5))

expwighted_avg = ts_log.ewm(halflife = 12).mean()
plt.plot(ts_log)
plt.plot(expwighted_avg, color='red')
plt.title('Log of Data Vs Exponentially Weighted MA of Log of Data', fontsize=20)
plt.show()

# %% [markdown]
# **Note:** the parameter ‘halflife’ is used to define the amount of exponential decay. This is just an assumption here and would depend largely on the business domain. Other parameters like span and center of mass can also be used to define decay . Lets remove this from series and check stationarity:

# %%
ts_log_ewma_diff = ts_log - expwighted_avg # Difference between log data and ewma data
test_stationarity(ts_log_ewma_diff.Passengers)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic : -3.6012624201616723
# p-value : 0.005736938801511978
# #Lags Used : 13
# Number of Observations Used : 130
# Reject the null hypothesis. Data is stationary

# %% [markdown]
# **Observations:**<br/>
# This TS has even lesser variations in mean and standard deviation in magnitude. Also, the test statistic is smaller than the critical value, p-value is less than 0.05,  reject null hypothesis. TS is stationary now.

# %% [markdown]
# ## <a id='6'> 7. Eliminating Trend and Seasonality </a>
#
# The simple trend reduction techniques discussed before don’t work in all cases, particularly the ones with high seasonality.<br/>
# Lets discuss another way of removing trend and seasonality:<br/>
# *1. Differencing* – taking the differece with a particular time lag<br/>
# *2. Decomposition* - modeling both trend and seasonality and removing them from the model.<br/>

# %% [markdown]
# **Differencing**
#
# One of the most common methods of dealing with both trend and seasonality is differencing. In this technique, we take the difference of the observation at a particular instant with that at the previous instant. This mostly works well in improving stationarity.

# %%
# Differencing
plt.figure(figsize=(20,5))
ts_log_diff = ts_log - ts_log.shift() # difference between particular time lag
plt.plot(ts_log_diff, label='Differnnce of log data and log shift data')
plt.title('Difference between each time lag', fontsize=20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# This appears to have reduced trend considerably. Lets verify using our plots:

# %%
ts_log_diff.dropna(inplace=True)
test_stationarity(ts_log_diff.Passengers)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic : -2.7171305983881284
# p-value : 0.0711205481508595
# #Lags Used : 14
# Number of Observations Used : 128
# Fail to reject the null hypothesis. Data is non-stationary

# %% [markdown]
# **Observations:** We can see that the mean and std variations have small variations with time. Also, the Dickey-Fuller test statistic is less than the 10% critical value, thus the TS is stationary with 90% confidence.

# %% [markdown]
# **Decomposition**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.figure(figsize=(20,5))
decomposition = seasonal_decompose(ts_log, model='additive', freq = 30)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts, label='Original')
plt.legend(loc='best')

plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')

plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')

plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# **Observations:**
# - if you see the above graph, there is a upwards trend.
# - There is no seasonality

# %% [markdown]
# **Lets remove trend from the data**

# %%
ts_log_decompose = ts_log.Passengers - trend
ts_log_decompose.dropna(inplace=True)
test_stationarity(ts_log_decompose.values)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic : -3.211111968582979
# p-value : 0.019350417744555974
# #Lags Used : 13
# Number of Observations Used : 100
# Reject the null hypothesis. Data is stationary

# %% [markdown]
# **Observations**<br/>
# The Dickey-Fuller test statistic is very significantly lower than the 5% critical value. Also p-value is less than threshold(0.05). Reject null hypothesis and proves that TS is stationary.

# %% [markdown]
# **Now the time series is stationary and there is no trend or seasonality. Lets decompose this series again and visualize the same**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
plt.figure(figsize=(20,5))
decomposition1 = seasonal_decompose(ts_log_decompose, model = 'additive', freq = 30)

trend1 = decomposition1.trend
seasonal1 = decomposition1.seasonal
residual1 = decomposition1.resid

plt.subplot(411)
plt.plot(ts, label='Original')
plt.legend(loc='best')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(20,5))
plt.subplot(412)
plt.plot(trend1, label='Trend')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Note: If you notice clearly, there is no trend in this timeseries as we have already removed it**

# %%
plt.figure(figsize=(20,7))
plt.subplot(413)
plt.plot(seasonal1,label='Seasonality')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Forecasting Time Series**

# %% [markdown]
# **ARIMA**
#
# ARIMA stands for **Auto-Regressive Integrated Moving Averages**. The ARIMA forecasting for a stationary time series is nothing but a linear (like a linear regression) equation. The predictors depend on the parameters **(p,d,q) of the ARIMA model**:
#
# **Number of AR (Auto-Regressive) terms (p):** AR terms are just lags of dependent variable. For instance if p is 5, the predictors for x(t) will be x(t-1)….x(t-5).<br/>
#
# **Number of MA (Moving Average) terms (q):** MA terms are lagged forecast errors in prediction equation. For instance if q is 5, the predictors for x(t) will be e(t-1)….e(t-5) where e(i) is the difference between the moving average at ith instant and actual value.<br/>
#
# **Number of Differences (d):** These are the number of nonseasonal differences, i.e. in this case we took the first order difference. So either we can pass that variable and put d=0 or pass the original variable and put d=1. Both will generate same results.<br/>
#
# An importance concern here is how to determine the value of ‘p’ and ‘q’. We use two plots to determine these numbers. Lets discuss them first.

# %% [markdown]
# ## <a id='7'> 8. ACF and PACF plots </a>

# %%
#ACF and PACF plots:
import statsmodels.api as sm
from statsmodels.tsa.stattools import acf, pacf


fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts_log_decompose.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(ts_log_decompose, lags=40, ax=ax2)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# **Observations:**<br/>
# In the above two plots, the blue shaded area on the either sides of 0 are the confidence interevals. These can be used to determine the ‘p’ and ‘q’ values.<br/>
# p – The lag value where the PACF chart crosses the upper confidence interval. If you notice closely, in this case p=1.<br/>
# q – The lag value crosses the confidence interval. q=2.<br/>

# %% [markdown]
# ## <a id='8'> 9. Algorithm Selection </a>
#
# *   List item
# *   List item

# %% [markdown]
# ## <a id='10'>10. Auto ARIMA</a>
#
# We will use auto-arima which will automatically pick the best hyperparamaters for time series modelling.

# %%
from pmdarima import auto_arima

# %%
ts.shape
# Out:
# (144, 1)

# %%
#divide into train and validation set
train = ts[:int(0.7*(len(ts)))]
test = ts[int(0.7*(len(ts))):]
print(train.shape)
print(test.shape)
# Out:
# (100, 1)
# (44, 1)

# %%
#training model
model = auto_arima(train, trace=True, start_p=1, start_q=1, start_P=0, start_Q=0,
                  max_p=8, max_q=8, max_P=8, max_Q=8, seasonal=True,m=12,
                  stepwise=False, suppress_warnings=True, D=1, max_D=8,
                  error_action='ignore',approximation = False)
#fitting model
model.fit(train)
# Out:
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=652.680, BIC=657.612, Time=0.065 seconds
# Fit ARIMA(0,1,0)x(0,1,1,12) [intercept=True]; AIC=649.037, BIC=656.435, Time=0.180 seconds
# Fit ARIMA(0,1,0)x(0,1,2,12) [intercept=True]; AIC=650.859, BIC=660.722, Time=0.449 seconds
# Fit ARIMA(0,1,0)x(0,1,3,12) [intercept=True]; AIC=650.661, BIC=662.990, Time=0.999 seconds
# Fit ARIMA(0,1,0)x(0,1,4,12) [intercept=True]; AIC=651.084, BIC=665.880, Time=2.668 seconds
# Fit ARIMA(0,1,0)x(0,1,5,12) [intercept=True]; AIC=652.350, BIC=669.612, Time=8.370 seconds
# Fit ARIMA(0,1,0)x(1,1,0,12) [intercept=True]; AIC=649.280, BIC=656.678, Time=0.214 seconds
# Fit ARIMA(0,1,0)x(1,1,1,12) [intercept=True]; AIC=650.955, BIC=660.819, Time=0.298 seconds
# Fit ARIMA(0,1,0)x(1,1,2,12) [intercept=True]; AIC=648.713, BIC=661.043, Time=2.192 seconds
# Fit ARIMA(0,1,0)x(1,1,3,12) [intercept=True]; AIC=648.958, BIC=663.754, Time=3.976 seconds
# Fit ARIMA(0,1,0)x(1,1,4,12) [intercept=True]; AIC=650.961, BIC=668.222, Time=5.789 seconds
# Fit ARIMA(0,1,0)x(2,1,0,12) [intercept=True]; AIC=650.660, BIC=660.524, Time=0.595 seconds
# Fit ARIMA(0,1,0)x(2,1,1,12) [intercept=True]; AIC=652.497, BIC=664.826, Time=1.160 seconds
# Fit ARIMA(0,1,0)x(2,1,2,12) [intercept=True]; AIC=649.203, BIC=663.999, Time=2.702 seconds
# Fit ARIMA(0,1,0)x(2,1,3,12) [intercept=True]; AIC=651.059, BIC=668.320, Time=5.033 seconds
# Fit ARIMA(0,1,0)x(3,1,0,12) [intercept=True]; AIC=651.920, BIC=664.250, Time=1.261 seconds
# Fit ARIMA(0,1,0)x(3,1,1,12) [intercept=True]; AIC=650.739, BIC=665.534, Time=7.026 seconds
# Fit ARIMA(0,1,0)x(3,1,2,12) [intercept=True]; AIC=650.877, BIC=668.138, Time=4.924 seconds
# Fit ARIMA(0,1,0)x(4,1,0,12) [intercept=True]; AIC=651.762, BIC=666.557, Time=2.557 seconds
# Fit ARIMA(0,1,0)x(4,1,1,12) [intercept=True]; AIC=651.845, BIC=669.106, Time=7.804 seconds
# Fit ARIMA(0,1,0)x(5,1,0,12) [intercept=True]; AIC=653.427, BIC=670.689, Time=4.550 seconds
# Fit ARIMA(0,1,1)x(0,1,0,12) [intercept=True]; AIC=647.944, BIC=655.342, Time=0.087 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=646.447, BIC=656.311, Time=0.377 seconds
# Fit ARIMA(0,1,1)x(0,1,2,12) [intercept=True]; AIC=647.592, BIC=659.921, Time=0.851 seconds
# Fit ARIMA(0,1,1)x(0,1,3,12) [intercept=True]; AIC=647.648, BIC=662.443, Time=1.562 seconds
# Fit ARIMA(0,1,1)x(0,1,4,12) [intercept=True]; AIC=647.119, BIC=664.380, Time=2.880 seconds
# Fit ARIMA(0,1,1)x(1,1,0,12) [intercept=True]; AIC=646.058, BIC=655.921, Time=0.237 seconds
# Fit ARIMA(0,1,1)x(1,1,1,12) [intercept=True]; AIC=648.051, BIC=660.380, Time=0.471 seconds
# Fit ARIMA(0,1,1)x(1,1,2,12) [intercept=True]; AIC=643.861, BIC=658.657, Time=2.755 seconds
# Fit ARIMA(0,1,1)x(1,1,3,12) [intercept=True]; AIC=644.979, BIC=662.241, Time=5.386 seconds
# Fit ARIMA(0,1,1)x(2,1,0,12) [intercept=True]; AIC=648.043, BIC=660.372, Time=0.594 seconds
# Fit ARIMA(0,1,1)x(2,1,1,12) [intercept=True]; AIC=646.222, BIC=661.017, Time=3.149 seconds
# Fit ARIMA(0,1,1)x(2,1,2,12) [intercept=True]; AIC=644.904, BIC=662.166, Time=2.313 seconds
# Fit ARIMA(0,1,1)x(3,1,0,12) [intercept=True]; AIC=648.800, BIC=663.596, Time=1.462 seconds
# Fit ARIMA(0,1,1)x(3,1,1,12) [intercept=True]; AIC=646.442, BIC=663.704, Time=5.123 seconds
# Fit ARIMA(0,1,1)x(4,1,0,12) [intercept=True]; AIC=647.286, BIC=664.547, Time=3.084 seconds
# Fit ARIMA(0,1,2)x(0,1,0,12) [intercept=True]; AIC=649.911, BIC=659.775, Time=0.124 seconds
# Fit ARIMA(0,1,2)x(0,1,1,12) [intercept=True]; AIC=648.408, BIC=660.737, Time=0.380 seconds
# Fit ARIMA(0,1,2)x(0,1,2,12) [intercept=True]; AIC=649.542, BIC=664.338, Time=0.885 seconds
# Fit ARIMA(0,1,2)x(0,1,3,12) [intercept=True]; AIC=649.416, BIC=666.678, Time=1.690 seconds
# Fit ARIMA(0,1,2)x(1,1,0,12) [intercept=True]; AIC=648.019, BIC=660.348, Time=0.388 seconds
# Fit ARIMA(0,1,2)x(1,1,1,12) [intercept=True]; AIC=650.013, BIC=664.808, Time=0.607 seconds
# Fit ARIMA(0,1,2)x(1,1,2,12) [intercept=True]; AIC=645.731, BIC=662.992, Time=3.097 seconds
# Fit ARIMA(0,1,2)x(2,1,0,12) [intercept=True]; AIC=650.006, BIC=664.801, Time=0.899 seconds
# Fit ARIMA(0,1,2)x(2,1,1,12) [intercept=True]; AIC=648.183, BIC=665.444, Time=3.233 seconds
# Fit ARIMA(0,1,2)x(3,1,0,12) [intercept=True]; AIC=650.687, BIC=667.949, Time=1.734 seconds
# Fit ARIMA(0,1,3)x(0,1,0,12) [intercept=True]; AIC=645.947, BIC=658.277, Time=0.157 seconds
# Fit ARIMA(0,1,3)x(0,1,1,12) [intercept=True]; AIC=644.657, BIC=659.453, Time=0.510 seconds
# Fit ARIMA(0,1,3)x(0,1,2,12) [intercept=True]; AIC=646.080, BIC=663.342, Time=1.086 seconds
# Fit ARIMA(0,1,3)x(1,1,0,12) [intercept=True]; AIC=644.345, BIC=659.140, Time=0.418 seconds
# Fit ARIMA(0,1,3)x(1,1,1,12) [intercept=True]; AIC=646.337, BIC=663.598, Time=0.872 seconds
# Fit ARIMA(0,1,3)x(2,1,0,12) [intercept=True]; AIC=646.331, BIC=663.593, Time=1.917 seconds
# Fit ARIMA(0,1,4)x(0,1,0,12) [intercept=True]; AIC=647.812, BIC=662.608, Time=0.601 seconds
# Fit ARIMA(0,1,4)x(0,1,1,12) [intercept=True]; AIC=645.596, BIC=662.857, Time=1.426 seconds
# Fit ARIMA(0,1,4)x(1,1,0,12) [intercept=True]; AIC=645.528, BIC=662.789, Time=1.132 seconds
# Fit ARIMA(0,1,5)x(0,1,0,12) [intercept=True]; AIC=649.524, BIC=666.785, Time=0.832 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=647.792, BIC=655.190, Time=0.166 seconds
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=646.338, BIC=656.201, Time=0.590 seconds
# Fit ARIMA(1,1,0)x(0,1,2,12) [intercept=True]; AIC=647.498, BIC=659.827, Time=1.483 seconds
# Fit ARIMA(1,1,0)x(0,1,3,12) [intercept=True]; AIC=647.848, BIC=662.644, Time=1.457 seconds
# Fit ARIMA(1,1,0)x(0,1,4,12) [intercept=True]; AIC=647.390, BIC=664.651, Time=3.702 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=645.940, BIC=655.803, Time=0.304 seconds
# Fit ARIMA(1,1,0)x(1,1,1,12) [intercept=True]; AIC=647.927, BIC=660.257, Time=0.448 seconds
# Fit ARIMA(1,1,0)x(1,1,2,12) [intercept=True]; AIC=644.082, BIC=658.878, Time=2.789 seconds
# Fit ARIMA(1,1,0)x(1,1,3,12) [intercept=True]; AIC=645.143, BIC=662.405, Time=4.019 seconds
# Fit ARIMA(1,1,0)x(2,1,0,12) [intercept=True]; AIC=647.914, BIC=660.244, Time=0.808 seconds
# Fit ARIMA(1,1,0)x(2,1,1,12) [intercept=True]; AIC=646.277, BIC=661.072, Time=2.860 seconds
# Fit ARIMA(1,1,0)x(2,1,2,12) [intercept=True]; AIC=645.038, BIC=662.299, Time=2.519 seconds
# Fit ARIMA(1,1,0)x(3,1,0,12) [intercept=True]; AIC=648.854, BIC=663.649, Time=1.657 seconds
# Fit ARIMA(1,1,0)x(3,1,1,12) [intercept=True]; AIC=646.687, BIC=663.949, Time=5.564 seconds
# Fit ARIMA(1,1,0)x(4,1,0,12) [intercept=True]; AIC=647.670, BIC=664.931, Time=3.113 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=649.156, BIC=659.019, Time=0.181 seconds
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=647.801, BIC=660.131, Time=0.449 seconds
# Fit ARIMA(1,1,1)x(0,1,2,12) [intercept=True]; AIC=649.022, BIC=663.818, Time=1.194 seconds
# Fit ARIMA(1,1,1)x(0,1,3,12) [intercept=True]; AIC=649.796, BIC=667.058, Time=2.772 seconds
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=647.405, BIC=659.734, Time=0.551 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=649.379, BIC=664.174, Time=0.904 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=642.922, BIC=660.183, Time=4.235 seconds
# Fit ARIMA(1,1,1)x(2,1,0,12) [intercept=True]; AIC=649.358, BIC=664.153, Time=1.395 seconds
# Fit ARIMA(1,1,1)x(2,1,1,12) [intercept=True]; AIC=648.112, BIC=665.374, Time=2.991 seconds
# Fit ARIMA(1,1,1)x(3,1,0,12) [intercept=True]; AIC=650.585, BIC=667.847, Time=2.600 seconds
# Fit ARIMA(1,1,2)x(0,1,0,12) [intercept=True]; AIC=650.917, BIC=663.246, Time=0.271 seconds
# Fit ARIMA(1,1,2)x(0,1,1,12) [intercept=True]; AIC=649.659, BIC=664.454, Time=0.685 seconds
# Fit ARIMA(1,1,2)x(0,1,2,12) [intercept=True]; AIC=650.773, BIC=668.035, Time=1.678 seconds
# Fit ARIMA(1,1,2)x(1,1,0,12) [intercept=True]; AIC=649.235, BIC=664.030, Time=0.615 seconds
# Fit ARIMA(1,1,2)x(1,1,1,12) [intercept=True]; AIC=651.194, BIC=668.455, Time=1.101 seconds
# Fit ARIMA(1,1,2)x(2,1,0,12) [intercept=True]; AIC=651.158, BIC=668.419, Time=1.502 seconds
# Fit ARIMA(1,1,3)x(0,1,0,12) [intercept=True]; AIC=647.855, BIC=662.650, Time=0.228 seconds
# Fit ARIMA(1,1,3)x(0,1,1,12) [intercept=True]; AIC=644.247, BIC=661.508, Time=1.821 seconds
# Fit ARIMA(1,1,3)x(1,1,0,12) [intercept=True]; AIC=645.676, BIC=662.937, Time=0.604 seconds
# Fit ARIMA(1,1,4)x(0,1,0,12) [intercept=True]; AIC=646.512, BIC=663.773, Time=0.884 seconds
# Fit ARIMA(2,1,0)x(0,1,0,12) [intercept=True]; AIC=649.670, BIC=659.533, Time=0.158 seconds
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=648.231, BIC=660.560, Time=0.416 seconds
# Fit ARIMA(2,1,0)x(0,1,2,12) [intercept=True]; AIC=649.410, BIC=664.206, Time=0.925 seconds
# Fit ARIMA(2,1,0)x(0,1,3,12) [intercept=True]; AIC=649.847, BIC=667.108, Time=1.856 seconds
# Fit ARIMA(2,1,0)x(1,1,0,12) [intercept=True]; AIC=647.833, BIC=660.163, Time=0.505 seconds
# Fit ARIMA(2,1,0)x(1,1,1,12) [intercept=True]; AIC=649.818, BIC=664.613, Time=0.724 seconds
# Fit ARIMA(2,1,0)x(1,1,2,12) [intercept=True]; AIC=646.086, BIC=663.347, Time=3.358 seconds
# Fit ARIMA(2,1,0)x(2,1,0,12) [intercept=True]; AIC=649.803, BIC=664.598, Time=1.132 seconds
# Fit ARIMA(2,1,0)x(2,1,1,12) [intercept=True]; AIC=648.247, BIC=665.508, Time=3.559 seconds
# Fit ARIMA(2,1,0)x(3,1,0,12) [intercept=True]; AIC=650.822, BIC=668.083, Time=1.949 seconds
# Fit ARIMA(2,1,1)x(0,1,0,12) [intercept=True]; AIC=651.061, BIC=663.390, Time=0.364 seconds
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=649.739, BIC=664.534, Time=0.710 seconds
# Fit ARIMA(2,1,1)x(0,1,2,12) [intercept=True]; AIC=650.919, BIC=668.180, Time=1.780 seconds
# Fit ARIMA(2,1,1)x(1,1,0,12) [intercept=True]; AIC=649.330, BIC=664.126, Time=0.729 seconds
# Fit ARIMA(2,1,1)x(1,1,1,12) [intercept=True]; AIC=651.299, BIC=668.560, Time=1.087 seconds
# Fit ARIMA(2,1,1)x(2,1,0,12) [intercept=True]; AIC=651.272, BIC=668.534, Time=1.785 seconds
# Fit ARIMA(2,1,2)x(0,1,0,12) [intercept=True]; AIC=646.341, BIC=661.137, Time=0.571 seconds
# Fit ARIMA(2,1,2)x(0,1,1,12) [intercept=True]; AIC=644.825, BIC=662.086, Time=1.469 seconds
# Fit ARIMA(2,1,2)x(1,1,0,12) [intercept=True]; AIC=644.567, BIC=661.828, Time=1.601 seconds
# Fit ARIMA(2,1,3)x(0,1,0,12) [intercept=True]; AIC=647.244, BIC=664.505, Time=0.822 seconds
# Fit ARIMA(3,1,0)x(0,1,0,12) [intercept=True]; AIC=648.086, BIC=660.416, Time=0.170 seconds
# Fit ARIMA(3,1,0)x(0,1,1,12) [intercept=True]; AIC=647.193, BIC=661.989, Time=0.355 seconds
# Fit ARIMA(3,1,0)x(0,1,2,12) [intercept=True]; AIC=648.353, BIC=665.615, Time=0.803 seconds
# Fit ARIMA(3,1,0)x(1,1,0,12) [intercept=True]; AIC=646.798, BIC=661.593, Time=0.611 seconds
# Fit ARIMA(3,1,0)x(1,1,1,12) [intercept=True]; AIC=648.728, BIC=665.989, Time=0.834 seconds
# Fit ARIMA(3,1,0)x(2,1,0,12) [intercept=True]; AIC=648.669, BIC=665.930, Time=1.162 seconds
# Fit ARIMA(3,1,1)x(0,1,0,12) [intercept=True]; AIC=648.892, BIC=663.688, Time=0.255 seconds
# Fit ARIMA(3,1,1)x(0,1,1,12) [intercept=True]; AIC=644.522, BIC=661.784, Time=1.625 seconds
# Fit ARIMA(3,1,1)x(1,1,0,12) [intercept=True]; AIC=644.418, BIC=661.679, Time=1.795 seconds
# Fit ARIMA(3,1,2)x(0,1,0,12) [intercept=True]; AIC=650.834, BIC=668.095, Time=0.422 seconds
# Fit ARIMA(4,1,0)x(0,1,0,12) [intercept=True]; AIC=648.553, BIC=663.349, Time=0.147 seconds
# Fit ARIMA(4,1,0)x(0,1,1,12) [intercept=True]; AIC=647.341, BIC=664.603, Time=0.621 seconds
# Fit ARIMA(4,1,0)x(1,1,0,12) [intercept=True]; AIC=646.998, BIC=664.259, Time=0.707 seconds
# Fit ARIMA(4,1,1)x(0,1,0,12) [intercept=True]; AIC=650.530, BIC=667.791, Time=0.391 seconds
# Fit ARIMA(5,1,0)x(0,1,0,12) [intercept=True]; AIC=650.519, BIC=667.780, Time=0.332 seconds
# Total fit time: 209.121 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(1, 1, 1), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(1, 1, 2, 12),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)

# %% [markdown]
# Best model has an order of (1,1,1) and seasonal_order of (1,1,2,12)

# %%
prediction = pd.DataFrame(model.predict(n_periods=44), index=test.index)
prediction.columns = ['Predicted Passengers']

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd

plt.figure(figsize=(10,6))
plt.plot(train,label='Training')
plt.plot(test,label='Test')
plt.plot(prediction,label='Predicted')
plt.legend(loc='upper center')

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
R2_score = r2_score(test, prediction)
print('R2_score: ',R2_score)

MSE = mean_absolute_error(test, prediction)
RMSE = np.sqrt(MSE)
print('RMSE: ', RMSE)
# Out:
# R2_score:  0.820986736359754
# RMSE:  5.296209511442623

# %%
dj_r2 = 1-(1-R2_score)*(44-1)/(44-1-1)
dj_r2
# Out:
# 0.8167245157968911
